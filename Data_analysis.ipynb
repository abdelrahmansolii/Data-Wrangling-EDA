# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('fake_customer_data_with_errors.csv')
df=data.copy()

# %%
df.head()
# Out:
#   CustomerID           Name   Age  Gender                      Email  \
# 0   CUST1000     Ali Hassan  72.0     NaN       ali.hassan@gmail.com
# 1   CUST1001      Fatma Ali   NaN  Female      fatma.ali@hotmail.com
# 2   CUST1002  Ahmed Mahmoud  -1.0    male  ahmed.mahmoud@hotmail.com
# 3   CUST1003    Ahmed Gaber  -1.0       F      ahmed.gaber@gmail.com
# 4   CUST1004    Ali Ibrahim  73.0       M      ali.ibrahim@yahoo.com
#
#          Phone  PurchaseAmount PurchaseDate ProductCategory  Rating  Unnamed  \
# 0  123456789.0          837.31   2023-10-12           Books     3.0      NaN
# 1          NaN          900.25   2023-02-23             NaN     3.0      NaN
# 2          NaN          761.72   2023-07-07            Toys     2.0      NaN
# 3          NaN          303.72   2023-12-30             NaN     2.0      NaN
# 4  987654321.0          635.81   2023-12-07        Clothing     2.0      NaN
#
#     Gender
# 0        NaN
# 1     Female
# 2       male
# 3          F
# 4          M

# %% [markdown]
# ### DATA Wrangling

# %%
df.columns
# Out:
# Index(['CustomerID', 'Name', 'Age', 'Gender', 'Email', 'Phone',
#        'PurchaseAmount', 'PurchaseDate', 'ProductCategory', 'Rating',
#        'Unnamed', '  Gender  '],
#       dtype='object')

# %%
df.shape
# Out:
# (2150, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2150 entries, 0 to 2149
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       2150 non-null   object
#  1   Name             2150 non-null   object
#  2   Age              1630 non-null   float64
#  3   Gender           1877 non-null   object
#  4   Email            2150 non-null   object
#  5   Phone            1072 non-null   float64
#  6   PurchaseAmount   2049 non-null   float64
#  7   PurchaseDate     2150 non-null   object
#  8   ProductCategory  1573 non-null   object
#  9   Rating           1821 non-null   float64
#  10  Unnamed          0 non-null      float64
#  11    Gender         1877 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 201.7+ KB

# %%
df.describe(include='all')
# Out:
#        CustomerID        Name          Age Gender                  Email  \
# count        2150        2150  1630.000000   1877                   2150
# unique       2100          48          NaN      6                    144
# top      CUST1231  Sara Gaber          NaN      M  sara.hassan@yahoo.com
# freq            2          60          NaN    346                     26
# mean          NaN         NaN    85.180982    NaN                    NaN
# std           NaN         NaN    86.794111    NaN                    NaN
# min           NaN         NaN    -1.000000    NaN                    NaN
# 25%           NaN         NaN    -1.000000    NaN                    NaN
# 50%           NaN         NaN    54.000000    NaN                    NaN
# 75%           NaN         NaN   200.000000    NaN                    NaN
# max           NaN         NaN   200.000000    NaN                    NaN
#
#                Phone  PurchaseAmount PurchaseDate ProductCategory  \
# ...

# %%
df.columns= df.columns.str.lower()

# %%
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
df.nunique()
# Out:
# customerid         2100
# name                 48
# age                  78
# gender                6
# email               144
# phone                 2
# purchaseamount     1991
# purchasedate        860
# productcategory       5
# rating                6
# unnamed               0
#   gender              6
# dtype: int64

# %%
df.isna().sum()
# Out:
# customerid            0
# name                  0
# age                 520
# gender              273
# email                 0
# phone              1078
# purchaseamount      101
# purchasedate          0
# productcategory     577
# rating              329
# unnamed            2150
#   gender            273
# dtype: int64

# %% [markdown]
# #### Cleaning DATA

# %%
df.columns
# Out:
# Index(['customerid', 'name', 'age', 'gender', 'email', 'phone',
#        'purchaseamount', 'purchasedate', 'productcategory', 'rating',
#        'unnamed', '  gender  '],
#       dtype='object')

# %%
df.drop(columns=['unnamed', '  gender  '],inplace=True)

# %%
df.sample(2)
# Out:
#      customerid         name    age  gender                  email  \
# 1230   CUST2230  Lina Hassan  200.0  Female  lina.hassan@yahoo.com
# 1038   CUST2038    Ali Smith   72.0     NaN    ali.smith@yahoo.com
#
#             phone  purchaseamount purchasedate productcategory  rating
# 1230  987654321.0           98.10   2024-10-05             NaN     1.0
# 1038          NaN          505.12   2023-05-14            Toys     4.0

# %%
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
df[df.duplicated()]
# Out:
#      customerid           name    age  gender                     email  \
# 2100   CUST2034    Ali Mahmoud   -1.0    male   ali.mahmoud@hotmail.com
# 2101   CUST2176    Ali Ibrahim  200.0       F     ali.ibrahim@gmail.com
# 2102   CUST1067     Sara Gaber    NaN     NaN      sara.gaber@yahoo.com
# 2103   CUST2330     John Gaber  200.0       M      john.gaber@gmail.com
# 2104   CUST1650   Lina Ibrahim  200.0       M  lina.ibrahim@hotmail.com
# 2105   CUST2868   Sara Mahmoud   -1.0    male    sara.mahmoud@gmail.com
# 2106   CUST1986       Sara Ali   90.0  female      sara.ali@hotmail.com
# 2107   CUST1552    Fatma Gaber    NaN  female     fatma.gaber@yahoo.com
# 2108   CUST2427  Fatma Mahmoud  200.0    Male   fatma.mahmoud@gmail.com
# 2109   CUST2668    Mark Hassan    NaN       M     mark.hassan@yahoo.com
# 2110   CUST2574   Sara Mahmoud   44.0  female    sara.mahmoud@yahoo.com
# 2111   CUST2317   Fatma Hassan  200.0       F    fatma.hassan@yahoo.com
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
#      customerid          name    age  gender                     email  \
# 29     CUST1029  John Mahmoud   67.0       F  john.mahmoud@hotmail.com
# 51     CUST1051     Ali Smith   -1.0       M       ali.smith@yahoo.com
# 67     CUST1067    Sara Gaber    NaN     NaN      sara.gaber@yahoo.com
# 70     CUST1070  Mark Mahmoud   81.0       F    mark.mahmoud@gmail.com
# 212    CUST1212  Sara Ibrahim  200.0       M  sara.ibrahim@hotmail.com
# ...         ...           ...    ...     ...                       ...
# 2145   CUST1447  Mark Mahmoud   66.0    male  mark.mahmoud@hotmail.com
# 2146   CUST1381  Fatma Hassan    NaN       M    fatma.hassan@yahoo.com
# 2147   CUST2338     Ali Gaber   -1.0       M       ali.gaber@gmail.com
# 2148   CUST1694      John Ali  200.0  Female        john.ali@yahoo.com
# 2149   CUST1567  Ahmed Hassan    NaN    male    ahmed.hassan@yahoo.com
#
#             phone  purchaseamount purchasedate productcategory  rating
# ...

# %%
df['name'][df['name'].duplicated()].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 15        Ali Ibrahim
# 18           Alaa Ali
# 20         Lina Gaber
# 22      Ahmed Mahmoud
# 23       Lina Ibrahim
#             ...
# 2145     Mark Mahmoud
# 2146     Fatma Hassan
# 2147        Ali Gaber
# 2148         John Ali
# 2149     Ahmed Hassan
# Name: name, Length: 2102, dtype: object>

# %%
df=df.rename(columns={'customerid' : 'customer_id' ,
                   'purchaseamount' : 'purchase_amount' ,
                  'purchasedate' : 'purchase_date' ,
                  'productcategory' : 'product_category' })

# %%
df['name'].value_counts()
# Out:
# name
# Sara Gaber       60
# Fatma Hassan     59
# Sara Hassan      59
# John Mahmoud     57
# Alaa Smith       57
# Sara Smith       54
# Lina Ibrahim     54
# Ali Smith        53
# Fatma Gaber      52
# Ali Hassan       52
# Sara Ali         52
# Fatma Ibrahim    51
# Alaa Gaber       49
# Ahmed Hassan     48
# Ali Ali          48
# John Smith       48
# Fatma Smith      47
# Lina Hassan      47
# Alaa Ali         46
# Ahmed Smith      45
# Lina Gaber       45
# Lina Smith       45
# Ahmed Ibrahim    45
# Sara Mahmoud     44
# Mark Mahmoud     44
# Lina Mahmoud     44
# Mark Ali         43
# Fatma Mahmoud    42
# John Hassan      42
# Ahmed Ali        42
# Ali Mahmoud      41
# Sara Ibrahim     41
# Ali Gaber        41
# John Ibrahim     41
# Alaa Mahmoud     41
# Mark Hassan      40
# Ali Ibrahim      40
# Alaa Hassan      39
# Mark Smith       39
# Alaa Ibrahim     38
# Fatma Ali        38
# Mark Ibrahim     38
# Lina Ali         36
# Ahmed Mahmoud    35
# John Gaber       35
# ...

# %%
df[(df['name'] == 'Mark Gaber')&(df.duplicated(subset=['name']))]
# Out:
#      customer_id        name    age  gender                   email  \
# 148     CUST1148  Mark Gaber   -1.0    Male    mark.gaber@gmail.com
# 259     CUST1259  Mark Gaber   -1.0     NaN  mark.gaber@hotmail.com
# 286     CUST1286  Mark Gaber    NaN  female  mark.gaber@hotmail.com
# 293     CUST1293  Mark Gaber   -1.0  female    mark.gaber@yahoo.com
# 402     CUST1402  Mark Gaber  200.0       M    mark.gaber@gmail.com
# 456     CUST1456  Mark Gaber   -1.0       M    mark.gaber@gmail.com
# 459     CUST1459  Mark Gaber    NaN       F  mark.gaber@hotmail.com
# 648     CUST1648  Mark Gaber   -1.0    male    mark.gaber@gmail.com
# 763     CUST1763  Mark Gaber   -1.0  Female    mark.gaber@gmail.com
# 788     CUST1788  Mark Gaber   32.0       F  mark.gaber@hotmail.com
# 867     CUST1867  Mark Gaber  200.0  Female    mark.gaber@yahoo.com
# 926     CUST1926  Mark Gaber    NaN  female  mark.gaber@hotmail.com
# 1218    CUST2218  Mark Gaber   20.0       M    mark.gaber@yahoo.com
# ...

# %%
df[df.duplicated(subset =['name'])]
# Out:
#      customer_id           name    age  gender                     email  \
# 15      CUST1015    Ali Ibrahim   18.0  female   ali.ibrahim@hotmail.com
# 18      CUST1018       Alaa Ali   15.0  Female      alaa.ali@hotmail.com
# 20      CUST1020     Lina Gaber    NaN       M    lina.gaber@hotmail.com
# 22      CUST1022  Ahmed Mahmoud   -1.0     NaN   ahmed.mahmoud@gmail.com
# 23      CUST1023   Lina Ibrahim   44.0       M    lina.ibrahim@yahoo.com
# ...          ...            ...    ...     ...                       ...
# 2145    CUST1447   Mark Mahmoud   66.0    male  mark.mahmoud@hotmail.com
# 2146    CUST1381   Fatma Hassan    NaN       M    fatma.hassan@yahoo.com
# 2147    CUST2338      Ali Gaber   -1.0       M       ali.gaber@gmail.com
# 2148    CUST1694       John Ali  200.0  Female        john.ali@yahoo.com
# 2149    CUST1567   Ahmed Hassan    NaN    male    ahmed.hassan@yahoo.com
#
#             phone  purchase_amount purchase_date product_category  rating
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'name', 'age', 'gender', 'email', 'phone',
#        'purchase_amount', 'purchase_date', 'product_category', 'rating'],
#       dtype='object')

# %%
for i in df.columns :
    print(f"count of {i} : ")
    print(df[i].nunique())
    print('\n')
# Out:
# count of customer_id :
# 2100
#
#
# count of name :
# 48
#
#
# count of age :
# 78
#
#
# count of gender :
# 6
#
#
# count of email :
# 144
#
#
# count of phone :
# 2
#
#
# count of purchase_amount :
# 1991
#
#
# count of purchase_date :
# 860
#
#
# count of product_category :
# 5
#
#
# count of rating :
# 6

# %%
for i in df.columns :
    print(f"describtion of {i} : ")
    print(df[i].describe())
    print('\n')
# Out:
# describtion of customer_id :
# count         2150
# unique        2100
# top       CUST1231
# freq             2
# Name: customer_id, dtype: object
#
#
# describtion of name :
# count           2150
# unique            48
# top       Sara Gaber
# freq              60
# Name: name, dtype: object
#
#
# describtion of age :
# count    1630.000000
# mean       85.180982
# std        86.794111
# min        -1.000000
# 25%        -1.000000
# 50%        54.000000
# 75%       200.000000
# max       200.000000
# Name: age, dtype: float64
#
#
# describtion of gender :
# count     1877
# unique       6
# top          M
# freq       346
# Name: gender, dtype: object
#
#
# describtion of email :
# count                      2150
# unique                      144
# top       sara.hassan@yahoo.com
# freq                         26
# Name: email, dtype: object
#
#
# describtion of phone :
# count    1.072000e+03
# mean     5.668417e+08
# std      4.321530e+08
# min      1.234568e+08
# ...

# %%
df.head()
# Out:
#   customer_id           name   age  gender                      email  \
# 0    CUST1000     Ali Hassan  72.0     NaN       ali.hassan@gmail.com
# 1    CUST1001      Fatma Ali   NaN  Female      fatma.ali@hotmail.com
# 2    CUST1002  Ahmed Mahmoud  -1.0    male  ahmed.mahmoud@hotmail.com
# 3    CUST1003    Ahmed Gaber  -1.0       F      ahmed.gaber@gmail.com
# 4    CUST1004    Ali Ibrahim  73.0       M      ali.ibrahim@yahoo.com
#
#          phone  purchase_amount purchase_date product_category  rating
# 0  123456789.0           837.31    2023-10-12            Books     3.0
# 1          NaN           900.25    2023-02-23              NaN     3.0
# 2          NaN           761.72    2023-07-07             Toys     2.0
# 3          NaN           303.72    2023-12-30              NaN     2.0
# 4  987654321.0           635.81    2023-12-07         Clothing     2.0

# %%
df['age'].isna().sum()
# Out:
# np.int64(520)

# %%
df.loc[(df['age']<0) | (df['age']>90) , 'age'] = np.nan

# %%
df['age'].isna().sum()
# Out:
# np.int64(1643)

# %%
df['age'].notna().sum()
# Out:
# np.int64(507)

# %% [markdown]
# ### Here we have to check if the age is critical ,  if it is so they have to send complete data else drop

# %%
df=df.drop(columns='age')

# %%
df.isna().sum()
# Out:
# customer_id            0
# name                   0
# gender               273
# email                  0
# phone               1078
# purchase_amount      101
# purchase_date          0
# product_category     577
# rating               329
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# M         346
# Female    314
# Male      313
# male      303
# F         302
# female    299
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].str.lower().replace({'m': 'male',
    'male': 'male',
    'f': 'female',
    'female': 'female'
})

# %%
df['gender'].value_counts()
# Out:
# gender
# male      962
# female    915
# Name: count, dtype: int64

# %%
df['gender'].isna().sum()
# Out:
# np.int64(273)

# %%
df[df['gender']=='male']['name'].unique()
# Out:
# array(['Ahmed Mahmoud', 'Ali Ibrahim', 'Mark Ali', 'John Hassan',
#        'Ahmed Smith', 'Sara Smith', 'Lina Gaber', 'Alaa Ali',
#        'John Mahmoud', 'Ahmed Ibrahim', 'Fatma Ibrahim', 'Lina Ibrahim',
#        'Sara Mahmoud', 'Ahmed Hassan', 'Lina Smith', 'Lina Mahmoud',
#        'Mark Gaber', 'Sara Hassan', 'Alaa Mahmoud', 'John Gaber',
#        'Fatma Mahmoud', 'Ali Smith', 'Ali Hassan', 'Ali Gaber',
#        'Sara Ali', 'Ali Ali', 'Ali Mahmoud', 'Lina Hassan', 'Fatma Smith',
#        'Lina Ali', 'Mark Mahmoud', 'John Ali', 'Sara Gaber',
#        'Fatma Gaber', 'Fatma Hassan', 'John Smith', 'Mark Hassan',
#        'Alaa Gaber', 'Ahmed Ali', 'Sara Ibrahim', 'Alaa Smith',
#        'Ahmed Gaber', 'John Ibrahim', 'Alaa Hassan', 'Mark Ibrahim',
#        'Alaa Ibrahim', 'Mark Smith', 'Fatma Ali'], dtype=object)

# %%
df=df.dropna(subset=['gender'])

# %%
df['gender'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### THis gender nulls and errors solved by manually iteration name by name , or send the right data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1877 entries, 1 to 2149
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1877 non-null   object
#  1   name              1877 non-null   object
#  2   gender            1877 non-null   object
#  3   email             1877 non-null   object
#  4   phone             940 non-null    float64
#  5   purchase_amount   1784 non-null   float64
#  6   purchase_date     1877 non-null   object
#  7   product_category  1377 non-null   object
#  8   rating            1591 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 146.6+ KB

# %%
df['phone'].value_counts()
# Out:
# phone
# 987654321.0    480
# 123456789.0    460
# Name: count, dtype: int64

# %%
df=df.dropna(subset=['phone'])

# %%
df[['purchase_amount' , 'product_category'  ]]=df[['purchase_amount' , 'product_category'  ]].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 940 entries, 4 to 2149
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       940 non-null    object
#  1   name              940 non-null    object
#  2   gender            940 non-null    object
#  3   email             940 non-null    object
#  4   phone             940 non-null    float64
#  5   purchase_amount   940 non-null    object
#  6   purchase_date     940 non-null    object
#  7   product_category  940 non-null    object
#  8   rating            809 non-null    float64
# dtypes: float64(2), object(7)
# memory usage: 73.4+ KB

# %%
df[df['purchase_date'].isna()]
# Out:
# Empty DataFrame
# Columns: [customer_id, name, gender, email, phone, purchase_amount, purchase_date, product_category, rating]
# Index: []

# %%
df[['purchase_date' , 'rating']]=df[['purchase_date' , 'rating']].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 940 entries, 4 to 2149
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       940 non-null    object
#  1   name              940 non-null    object
#  2   gender            940 non-null    object
#  3   email             940 non-null    object
#  4   phone             940 non-null    float64
#  5   purchase_amount   940 non-null    object
#  6   purchase_date     940 non-null    object
#  7   product_category  940 non-null    object
#  8   rating            940 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 73.4+ KB

# %% [markdown]
# ### Change dt from obj

# %%
#df=df.apply(lambda col:pd.to_numeric(col,errors='coerce') if col.dtype=='O' else col)

# %%
# better to try that on var first not on real df

# %%
df[['purchase_amount', 'rating', 'phone']] = df[['purchase_amount', 'rating', 'phone']].apply(pd.to_numeric, errors='coerce')

# %%
df['gender']=df['gender'].map({'male': 1, 'female': 0})

# %%
df.head()
# Out:
#    customer_id          name  gender                     email        phone  \
# 4     CUST1004   Ali Ibrahim       1     ali.ibrahim@yahoo.com  987654321.0
# 5     CUST1005  Alaa Ibrahim       0  alaa.ibrahim@hotmail.com  987654321.0
# 7     CUST1007   Alaa Hassan       0   alaa.hassan@hotmail.com  987654321.0
# 10    CUST1010   Ahmed Smith       1     ahmed.smith@gmail.com  987654321.0
# 15    CUST1015   Ali Ibrahim       0   ali.ibrahim@hotmail.com  123456789.0
#
#     purchase_amount purchase_date product_category  rating
# 4            635.81    2023-12-07         Clothing     2.0
# 5            886.26    2025-01-16          Unknown     2.0
# 7            318.43    2024-05-17             Toys    10.0
# 10           882.19    2025-06-24          Unknown     3.0
# 15           337.49    2024-06-25             Home     1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 940 entries, 4 to 2149
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       940 non-null    object
#  1   name              940 non-null    object
#  2   gender            940 non-null    int64
#  3   email             940 non-null    object
#  4   phone             940 non-null    float64
#  5   purchase_amount   898 non-null    float64
#  6   purchase_date     940 non-null    object
#  7   product_category  940 non-null    object
#  8   rating            809 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 73.4+ KB

# %%
df['purchase_date']=pd.to_datetime(df['purchase_date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df['purchase_date']=pd.to_datetime(df['purchase_date'])
#
# File D:\Anaconda\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File D:\Anaconda\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
# ...

# %%
df['purchase_date'].dtype
# Out:
# dtype('O')

# %%
df.loc[pd.to_datetime(df['purchase_date'], errors='coerce', dayfirst=True).isna(), 'purchase_date']
# Out:
# 5       2025-01-16
# 7       2024-05-17
# 10      2025-06-24
# 15      2024-06-25
# 19      32/13/2020
#            ...
# 2129    2023-12-18
# 2137    2023-05-14
# 2141    2025-06-22
# 2142    2024-07-17
# 2149    2023-10-13
# Name: purchase_date, Length: 584, dtype: object

# %%
df[pd.to_datetime(df['purchase_date'], errors='coerce', dayfirst=True).isna()]
# Out:
#      customer_id           name  gender                     email  \
# 5       CUST1005   Alaa Ibrahim       0  alaa.ibrahim@hotmail.com
# 7       CUST1007    Alaa Hassan       0   alaa.hassan@hotmail.com
# 10      CUST1010    Ahmed Smith       1     ahmed.smith@gmail.com
# 15      CUST1015    Ali Ibrahim       0   ali.ibrahim@hotmail.com
# 19      CUST1019  Ahmed Ibrahim       1   ahmed.ibrahim@yahoo.com
# ...          ...            ...     ...                       ...
# 2129    CUST1583    Sara Hassan       0     sara.hassan@gmail.com
# 2137    CUST2374      Ali Smith       1       ali.smith@yahoo.com
# 2141    CUST1212   Sara Ibrahim       1  sara.ibrahim@hotmail.com
# 2142    CUST1307   Fatma Hassan       0    fatma.hassan@gmail.com
# 2149    CUST1567   Ahmed Hassan       1    ahmed.hassan@yahoo.com
#
#             phone  purchase_amount purchase_date product_category  rating
# 5     987654321.0           886.26    2025-01-16          Unknown     2.0
# ...

# %%
df['purchase_date'] = pd.to_datetime(df['purchase_date'], errors='coerce', dayfirst=True)
df['purchase_date'] = df['purchase_date'].fillna('Unknown')

# %%
df.loc[df['purchase_date'] == 'Unknown', 'purchase_date'] = np.nan
df['purchase_date'] = pd.to_datetime(df['purchase_date'], errors='coerce', dayfirst=True)

# %%
df['purchase_date'] = pd.to_datetime(df['purchase_date'], errors='coerce', dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 940 entries, 4 to 2149
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       940 non-null    object
#  1   name              940 non-null    object
#  2   gender            940 non-null    int64
#  3   email             940 non-null    object
#  4   phone             940 non-null    float64
#  5   purchase_amount   898 non-null    float64
#  6   purchase_date     356 non-null    datetime64[ns]
#  7   product_category  940 non-null    object
#  8   rating            809 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 73.4+ KB

# %%
df = df.dropna(subset=['purchase_date', 'purchase_amount','rating'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 4 to 2148
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       302 non-null    object
#  1   name              302 non-null    object
#  2   gender            302 non-null    int64
#  3   email             302 non-null    object
#  4   phone             302 non-null    float64
#  5   purchase_amount   302 non-null    float64
#  6   purchase_date     302 non-null    datetime64[ns]
#  7   product_category  302 non-null    object
#  8   rating            302 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 23.6+ KB

# %% [markdown]
# ### The Data is bad and not sufficient but its clean .

# %%
df.to_csv("cleaned_df.csv",index=False)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\abdo_\\My_Current_scratching'
